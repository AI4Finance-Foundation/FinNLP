# %%
import sys
sys.path.append("..")

# %% [markdown]
# #### Imports

# %%
from finnlp.data_sources.news.tushare_major_news import Tushare_Major_News

# %% [markdown]
# #### Config

# %%
start_date = "2022-01-01"
end_date = "2022-01-05"

# %% [markdown]
# #### News_downloader

# %%
news_downloader = Tushare_finance()

# %%
news_downloader.download_news(start_date,end_date)
# Out:
#   0%|          | 0/5 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_133628\3989121806.py in <module>
# ----> 1 news_downloader.download_news(start_date,end_date)
#
# ~\AppData\Local\Temp\ipykernel_133628\3702496861.py in download_news(self, start_date, end_date, stock)
#      15         res = pd.DataFrame()
#      16         for date in tqdm(self.date_list):
# ---> 17             tmp = self.gather_one_day_news(date)
#      18             res = pd.concat([res,tmp])
#      19         self.dataframe = res
#
# ~\AppData\Local\Temp\ipykernel_133628\3702496861.py in gather_one_day_news(self, date, stock, delay)
#      21     def gather_one_day_news(self,date,stock = "all",delay = 0.1):
#      22         date = self.transfer_standard_date_to_nonstandard(date)
# ...

# %%
news_downloader.dataframe.shape
# Out:
# (60, 3)

# %%
news_downloader.dataframe
# Out:
#                                                 title             pub_time  \
# 0   市政协委员、奇安信集团董事长齐向东：建议北京市推进“第三方数据监管平台”和“跨行业反诈大数据...  2022-01-04 23:59:24
# 1                  新增30家！海珠公布第二批校外培训机构预收费资金监管账户，家长要留心  2022-01-04 23:45:12
# 2        市政协委员、北京市石景山区督查督办科科长杨朝霞：尽快对全市6100余个“骑沿井”进行改造  2022-01-04 23:43:55
# 3                          延庆区教委：区内冰雪技能普及人数累计达到3.1万余人  2022-01-04 23:35:26
# 4                                   RCEP生效 为全球经济注入新动能  2022-01-04 23:33:46
# 5   关于召开“2021年度江苏省钢铁行业十大新闻”、“2021年度钢铁工业十大技术成果”等专家评...  2022-01-04 23:32:18
# 6                3450万元卖参股公司0.23%股权 2名独董投弃权票 诚迈科技收关注函  2022-01-04 23:25:38
# 7                     天津《企业开办登记规范》地方标准发布 助企业开办1个工作日办结  2022-01-04 23:22:40
# 8                                     我国将实施企业信用风险分类管理  2022-01-04 23:22:27
# 9                                    德国去年12月失业率降至5.2%  2022-01-04 23:21:18
# 10                               元旦假期南京共出行约1197.89万人次  2022-01-04 23:16:38
# ...
