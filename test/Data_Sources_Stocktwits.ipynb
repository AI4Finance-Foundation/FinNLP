# %%
import sys
sys.path.append("..")

# %% [markdown]
# #### Import

# %%
from finnlp.data_sources.social_media.stocktwits import Stocktwits_Downloader

# %% [markdown]
# #### Config

# %%
stock = "AAPL"

# %% [markdown]
# #### Downloader

# %%
downloader = Stocktwits_Downloader()

# %%
downloader.download_newest(stock = stock)
# Out:
#   0%|          | 0/3 [00:00<?, ?it/s]

# %%
downloader.dataframe.shape
# Out:
# (90, 17)

# %%
downloader.dataframe
# Out:
#            id                                               body  \
# 0   515635193  $AAPL  $QQQ  Analyst price..&#39;] target ..fo...
# 1   515634698  $AAPL https://newsfilter.io/articles/update-1-...
# 2   515634152  $AAPL Foxconn reports fall in Feb sales, stick...
# 3   515634110  $AAPL how’d that work out for u LOL shit poppe...
# 4   515633853  $AAPL Short term can see 152.24 next followed ...
# ..        ...                                                ...
# 85  515614909  My alerts for LARGE caps. I have timestamps + ...
# 86  515614894  $DIS $AAPL $QQQ The REAL Walt Disney Story!\n\...
# 87  515612452  $SPY Trump is the savior of the nation!!!! God...
# 88  515612356  $AAPL was analyzed by 48 analysts. The buy con...
# 89  515611462  $AAPL  Huge explosion  this afternoon In Frede...
#
#               created_at                                               user  \
# 0   2023-03-05T09:22:37Z  {'id': 6656839, 'username': 'KendallEaston', '...
# ...
